# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-10/blob/main/AI_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AI TASK 1**

# %% [markdown]
# ***Evaluate the following expressions***

# %%
10+20/5-3*2
# Out:
# 8.0

# %%
(23+5)*7/5+(3*2)
# Out:
# 45.2

# %%
45//2+(6+5)*2
# Out:
# 44

# %%
16%3+56-4+(35//5)
# Out:
# 60

# %%
12+56-16*4%3*3
# Out:
# 65
