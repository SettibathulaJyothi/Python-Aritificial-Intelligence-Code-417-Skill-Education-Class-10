# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-10/blob/main/Print_%26_Input_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Print() Function**
# * The print() function is used to printan output on the screen
# * It converts the expression into a string before writing to the screen
# * Syntax:print(object(s),sep=separator,end=end)
#   * where *object* can be more or one seperated by comma and it can be a variable.Object is converted to string before printing
#   * where *sep* seperator between the items to print,Default sep is space
#   * where *end* allows to specify what to print at the end of the output.default is newline character ('\n') means each print statement ends with a nwe line
#
# **Following are the examples of the print() function**

# %%
print("Good")
# Out:
# Good

# %%
print("Good","Morning")
# Out:
# Good Morning

# %%
print("hi"+"how are you")#(This is concatenation of string using "+" operator)
# Out:
# hihow are you

# %%
print("trends","following",sep="$")
# Out:
# trends$following

# %%
print("trends","following",sep="$",end="!")
# Out:
# trends$following!

# %%
print("hello","friends",end="!")
# Out:
# hello friends!

# %%
print("hello")
# Out:
# hello

# %%
print()

# %%
print("friends")
# Out:
# friends

# %%
print("hello",end="%")
# Out:
# hello%

# %%
print("hello","friends","welcome",sep="%",end="@")
# Out:
# hello%friends%welcome@

# %%
print("I am in class ", 9)
# Out:
# I am in class  9

# %%
a=5
b=10
print("sum of two numbers is",str(a+b))
# Out:
# sum of two numbers is 15

# %%
age=14
print("I am",age,"years old")
# Out:
# I am 14 years old

# %% [markdown]
# # **The Input() Function**
# * This is used to take input from the user.
# * When this statement executes, the flow of program stops and waits with the cursor blinking for the user to enter a vlaue
# * The input given by user is always a **string value in python**
# * The syntax is:\
#   input(prompt)

# %%
name=input("enter your name")
print(name)
# Out:
# enter your nameJyothi
# Jyothi

# %%
N1=input("Enter first number:")
N2=input("Enter second number:")
sum=N1+N2
print("sum= ",sum)
# Out:
# Enter first number:9
# Enter second number:7
# sum=  97

# %%
a=int(input("Enter first number:"))
b=float(input("Enter second number:"))
#print(a)
#print(b)
# Out:
# Enter first number:4
# Enter second number:5

# %%
N1=int(input("Enter first number:"))
N2=int(input("Enter second number:"))
sum=N1+N2
print("The sum of",N1,"and",N2,"is",sum)
# Out:
# Enter first number:8
# Enter second number:9
# The sum of 8 and 9 is 17
